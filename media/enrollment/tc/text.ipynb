# %%
word = input("enter the word")

count = 0
for _ in word:
    count += 1
w = ""
while 0 < count:
    w = w + word[count-1]
    count -= 1

if word == w:
    print("given string is palindrome")
else:
    print("not a palindrome")
# Out:
# not a palindrome

# %%
a = [
    {"name" : "sai"},
    {"name" : "nang"},
    {"name" : "sai"},
    {"name" : "nang"},
    {"name" : "111111"},
    {"name" : "Gowtham"}
     ]


result = []

for i in a :
    if i not in result:
        result = result + [i]
print(result)
# Out:
# [{'name': 'sai'}, {'name': 'nang'}, {'name': '111111'}, {'name': 'Gowtham'}]

# %%
s = input("enter the input ")

count = 0
for _ in word:
    count += 1

w = ""
while 0 <= count:
    w = w + s[count]
    count -= 1

print(w)
# Out:
# ahpla
